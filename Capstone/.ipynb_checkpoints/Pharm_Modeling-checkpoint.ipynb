# %% [markdown]
# # Predicting Pharmaceutical Drug Sales in South Korea
# From the initial EDA, we discussed the relationships between several features and gas generation in South Korea. However, while exploring those features, we found that some aspects (especially infectious disease and pharmaceutical sales) didn't really have significant connections to gas generation. Therefore, we will instead explore a pivoted idea, instead prediction the total pharmaceutical drug sales using the afformentioned features.
#
# A condensed feature correlation plot is shown below to summarize the relationships we found with the different explored features. Further information can be found in the initial EDA notebook: https://github.com/kevinjin21/SpringboardProjects/blob/main/Capstone/Korea%20Gas%20and%20Electricity%20Comprehensive%20EDA.ipynb

# %% [markdown]
# <div>
# <img src="Data/feature_correlation_all.png" width=1000/>
# </div>

# %% [markdown]
# ## Import data and dependencies

# %%
# Extensions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import date
# %matplotlib inline

# %%
# Modeling 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict, cross_val_score, KFold
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold

from sklearn.preprocessing import MinMaxScaler

from sklearn import metrics

# %%
# Pharmaceutical dataset - all features
df = pd.read_excel('Data/Korea_Data_All.xlsx', sheet_name='PHARM_ALL')
df
# Out:
#      Year  Month  Total Sales  Seoul_1  Seoul_2  Seoul_3  Seoul_4  \
# 0    2008      1       356295     69.0   2620.0   9594.0      8.0
# 1    2008      2       356295      NaN      NaN      NaN      NaN
# 2    2008      3       356295      NaN      NaN      NaN      NaN
# 3    2008      4       356295      NaN      NaN      NaN      NaN
# 4    2008      5       356295      NaN      NaN      NaN      NaN
# ..    ...    ...          ...      ...      ...      ...      ...
# 163  2021      8       670686      NaN      NaN      NaN      NaN
# 164  2021      9       670686      NaN      NaN      NaN      NaN
# 165  2021     10       670686      NaN      NaN      NaN      NaN
# 166  2021     11       670686      NaN      NaN      NaN      NaN
# 167  2021     12       670686      NaN      NaN      NaN      NaN
#
#      Total_Surgeries  Seoul_Accidents  Seoul_Deaths  ...  Seoul_Gas  \
# 0             155338             2607            38  ...   822116.0
# 1             125656             2562            32  ...   806820.0
# 2             135139             3189            44  ...   611034.0
# 3             125437             3399            44  ...   397143.0
# 4             123598             3838            36  ...   246734.0
# ..               ...              ...           ...  ...        ...
# 163           161749             2778            25  ...        NaN
# 164           154439             2737            24  ...        NaN
# 165           174234             2814            24  ...        NaN
# 166           181995             2925            19  ...        NaN
# 167           189431             2869            26  ...        NaN
#
#      Seoul_Temp  Seoul_O3  Seoul_SO3  Seoul_NO2  Seoul_CO  Gyeonggi_PM10  \
# 0          -1.7  0.011889   0.007667   0.039222  0.755556      61.666667
# 1          -1.2  0.014111   0.006556   0.042111  0.788889      69.555556
# 2           7.3  0.025000   0.005000   0.031000  0.500000      69.777778
# 3          14.1  0.026889   0.004556   0.035333  0.500000      62.000000
# 4          17.7  0.029556   0.005111   0.034444  0.500000      71.888889
# ..          ...       ...        ...        ...       ...            ...
# 163         NaN  0.034000   0.003000   0.015000  0.400000      25.000000
# 164         NaN  0.031000   0.003000   0.014000  0.400000      17.000000
# 165         NaN  0.022000   0.003000   0.022000  0.400000      31.000000
# 166         NaN  0.018000   0.003000   0.031000  0.600000      48.000000
# 167         NaN  0.014000   0.003000   0.031000  0.600000      41.000000
#
#      Seoul Total Precipitation (mm)  Seoul Mean Wind Speed (m/s)  \
# 0                              17.7                          2.3
# 1                              15.0                          2.7
# 2                              53.9                          2.6
# 3                              38.5                          2.7
# 4                              97.7                          2.7
# ..                              ...                          ...
# 163                           211.2                          2.1
# 164                           131.0                          2.3
# 165                            57.0                          2.1
# 166                            62.4                          2.1
# 167                             7.9                          2.3
#
#      Seoul Mean Rel. Humid. (%)
# 0                            50
# 1                            46
# 2                            56
# 3                            50
# 4                            58
# ..                          ...
# 163                          74
# 164                          71
# 165                          70
# 166                          68
# 167                          62
#
# [168 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              168 non-null    int64
#  1   Month                             168 non-null    int64
#  2   Total Sales                       168 non-null    int64
#  3   Seoul_1                           12 non-null     float64
#  4   Seoul_2                           12 non-null     float64
#  5   Seoul_3                           12 non-null     float64
#  6   Seoul_4                           12 non-null     float64
#  7   Total_Surgeries                   168 non-null    int64
#  8   Seoul_Accidents                   168 non-null    int64
#  9   Seoul_Deaths                      168 non-null    int64
#  10  Seoul_Injured                     168 non-null    int64
#  11  International flight (passenger)  156 non-null    float64
#  12  Domestic flight (passenger)       156 non-null    float64
#  13  Total_Buildings                   168 non-null    int64
#  14  Masonry_Buildings                 168 non-null    int64
#  15  Other_Material_Buildings          168 non-null    int64
#  16  Industrial_Use_Buildings          168 non-null    int64
#  17  Edu_Social_Use_Buildings          168 non-null    int64
#  18  Other_Use_Buildings               168 non-null    int64
#  19  Total_Fires                       14 non-null     float64
#  20  Seoul_Fires                       14 non-null     float64
#  21  Seoul_Elec                        156 non-null    float64
#  22  Seoul_Gas                         156 non-null    float64
#  23  Seoul_Temp                        156 non-null    float64
#  24  Seoul_O3                          168 non-null    float64
#  25  Seoul_SO3                         168 non-null    float64
#  26  Seoul_NO2                         168 non-null    float64
#  27  Seoul_CO                          168 non-null    float64
#  28  Gyeonggi_PM10                     168 non-null    float64
#  29  Seoul Total Precipitation (mm)    168 non-null    float64
#  30  Seoul Mean Wind Speed (m/s)       168 non-null    float64
#  31  Seoul Mean Rel. Humid. (%)        168 non-null    int64
# dtypes: float64(18), int64(14)
# memory usage: 42.1 KB

# %% [markdown]
# ## Clean the dataset

# %% [markdown]
# Above, we can see the different feature names, and as observed in the full 'df' dataframe, there are quite a bit of missing values. These come from two main sources:
#
# 1. The total sales data ranges from Jan 2008 to Dec 2021. Some datasets don't go all the way to the end of 2021, so we'll remove the trailing data, instead ending at the end of 2019.
# 2. Some data are annual, meaning they only have one entry per year. We will use forward fill (ffill) to create a stepwise monthly value for these data. (Note: This was also done for the pharmaceutical data)

# %% [markdown]
# ### 1. Trailing Data removal

# %% [markdown]
# The Seoul1-4 (infectious disease) data only has 12 values, representing 12 years worth of data. This means the dataset should end at 2019 instead of 2021, as it starts in 2008. We will remove the extra rows.

# %%
df = df[df.Year < 2020]
df.tail(12)
# Out:
#      Year  Month  Total Sales  Seoul_1  Seoul_2  Seoul_3  Seoul_4  \
# 132  2019      1       599303   3251.0  12115.0  12544.0    107.0
# 133  2019      2       599303      NaN      NaN      NaN      NaN
# 134  2019      3       599303      NaN      NaN      NaN      NaN
# 135  2019      4       599303      NaN      NaN      NaN      NaN
# 136  2019      5       599303      NaN      NaN      NaN      NaN
# 137  2019      6       599303      NaN      NaN      NaN      NaN
# 138  2019      7       599303      NaN      NaN      NaN      NaN
# 139  2019      8       599303      NaN      NaN      NaN      NaN
# 140  2019      9       599303      NaN      NaN      NaN      NaN
# 141  2019     10       599303      NaN      NaN      NaN      NaN
# 142  2019     11       599303      NaN      NaN      NaN      NaN
# 143  2019     12       599303      NaN      NaN      NaN      NaN
#
#      Total_Surgeries  Seoul_Accidents  Seoul_Deaths  ...  Seoul_Gas  \
# 132           199086             2983            25  ...   754822.0
# 133           157978             2482            13  ...   662117.0
# 134           176493             3099            22  ...   479716.0
# 135           174041             3283            14  ...   371517.0
# 136           170519             3497            24  ...   227515.0
# 137           151257             3290            20  ...   172980.0
# 138           168460             3311            15  ...   172649.0
# 139           151009             3447            22  ...   160321.0
# 140           147525             3313            25  ...   155577.0
# 141           162983             3634            31  ...   185075.0
# 142           162495             3669            14  ...   364952.0
# 143           174415             3250            25  ...   588558.0
#
#      Seoul_Temp  Seoul_O3  Seoul_SO3  Seoul_NO2  Seoul_CO  Gyeonggi_PM10  \
# 132        -0.9     0.012      0.005      0.039       0.8           72.0
# 133         1.0     0.018      0.005      0.036       0.7           61.0
# 134         7.1     0.028      0.005      0.034       0.6           72.0
# 135        12.1     0.029      0.004      0.029       0.5           45.0
# 136        19.4     0.043      0.005      0.028       0.5           56.0
# 137        22.5     0.039      0.004      0.020       0.4           32.0
# 138        25.9     0.031      0.004      0.018       0.4           30.0
# 139        27.2     0.030      0.004      0.018       0.4           29.0
# 140        22.6     0.024      0.003      0.021       0.4           26.0
# 141        16.4     0.021      0.003      0.025       0.5           37.0
# 142         7.6     0.013      0.004      0.034       0.6           47.0
# 143         1.4     0.011      0.004      0.035       0.7           47.0
#
#      Seoul Total Precipitation (mm)  Seoul Mean Wind Speed (m/s)  \
# 132                             0.0                          1.8
# 133                            23.8                          1.8
# 134                            26.8                          2.1
# 135                            47.3                          1.9
# 136                            37.8                          2.1
# 137                            74.0                          1.7
# 138                           194.4                          1.8
# 139                           190.5                          1.6
# 140                           139.8                          2.2
# 141                            55.5                          2.1
# 142                            78.8                          2.2
# 143                            22.6                          2.1
#
#      Seoul Mean Rel. Humid. (%)
# 132                          46
# 133                          47
# 134                          51
# 135                          51
# 136                          47
# 137                          61
# 138                          69
# 139                          69
# 140                          65
# 141                          62
# 142                          56
# 143                          58
#
# [12 rows x 32 columns]

# %% [markdown]
# ### 2. Forward fill annual data
# As mentioned above, some data are annual in nature. We will forward fill the values to create stepwise monthly data.

# %%
df = df.fillna(method='ffill')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 143
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              144 non-null    int64
#  1   Month                             144 non-null    int64
#  2   Total Sales                       144 non-null    int64
#  3   Seoul_1                           144 non-null    float64
#  4   Seoul_2                           144 non-null    float64
#  5   Seoul_3                           144 non-null    float64
#  6   Seoul_4                           144 non-null    float64
#  7   Total_Surgeries                   144 non-null    int64
#  8   Seoul_Accidents                   144 non-null    int64
#  9   Seoul_Deaths                      144 non-null    int64
#  10  Seoul_Injured                     144 non-null    int64
#  11  International flight (passenger)  144 non-null    float64
#  12  Domestic flight (passenger)       144 non-null    float64
#  13  Total_Buildings                   144 non-null    int64
#  14  Masonry_Buildings                 144 non-null    int64
#  15  Other_Material_Buildings          144 non-null    int64
#  16  Industrial_Use_Buildings          144 non-null    int64
#  17  Edu_Social_Use_Buildings          144 non-null    int64
#  18  Other_Use_Buildings               144 non-null    int64
#  19  Total_Fires                       144 non-null    float64
#  20  Seoul_Fires                       144 non-null    float64
#  21  Seoul_Elec                        144 non-null    float64
#  22  Seoul_Gas                         144 non-null    float64
#  23  Seoul_Temp                        144 non-null    float64
#  24  Seoul_O3                          144 non-null    float64
#  25  Seoul_SO3                         144 non-null    float64
#  26  Seoul_NO2                         144 non-null    float64
#  27  Seoul_CO                          144 non-null    float64
#  28  Gyeonggi_PM10                     144 non-null    float64
#  29  Seoul Total Precipitation (mm)    144 non-null    float64
#  30  Seoul Mean Wind Speed (m/s)       144 non-null    float64
#  31  Seoul Mean Rel. Humid. (%)        144 non-null    int64
# dtypes: float64(18), int64(14)
# memory usage: 37.1 KB

# %% [markdown]
# Everything is now uniform across the board, with the same number of values per feature and over the same time period. Let's get to initial modeling.

# %% [markdown]
# # Modeling
# We have many features in this dataset. We'll first try modeling with *all features included* to see initially how the model can perform, and to provide a baseline standard for the predictive value of this model.
#
# <u>Target</u>: Annual Pharmaceutical Total Sales in Korea (year 2008-2019)
# <br><u>Features</u>: Infectious Disease (Type 1-4), Total Surgeries, Accidents and Injuries/Deaths, International and Domestic flights, Total Constructed Buildings, Buildings Constructed with Certain Materials, Buildings Constructed for Certain Purposes, Total Fires, Gas and Electricity Generation, Temperature, Pollutant Data, and Weather Data.
#
# The model we will try is a Random Forest, as it proved to perform the best in our initial modeling (Check the 'Modeling' notebook). Later on we may experiment with other models as well.

# %% [markdown]
# ## Random Forest - Untuned, all features
# Let's train a simple random forest to act as a baseline for the predictive strength of our features.

# %% [markdown]
# ### Normalize Data
# It is visible above, but the data we are dealing with is highly irregular in scale across the different features. We'll normalize it with a normalizing function before splitting the data or modeling. The features and target will then all be ranging from 0-1.

# %%
# Using our normalizing function from before:
def normalize(df):
    for column in df.columns:
        df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min()) 
    return df

# %%
norm_df = normalize(df)
norm_df.describe()
# Out:
#              Year       Month  Total Sales     Seoul_1     Seoul_2  \
# count  144.000000  144.000000   144.000000  144.000000  144.000000
# mean     0.500000    0.500000     0.473135    0.202291    0.407831
# std      0.314918    0.314918     0.291292    0.267137    0.334690
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      0.250000    0.250000     0.298517    0.055399    0.144293
# 50%      0.500000    0.500000     0.423679    0.092593    0.387729
# 75%      0.750000    0.750000     0.688904    0.272207    0.587542
# max      1.000000    1.000000     1.000000    1.000000    1.000000
#
#           Seoul_3     Seoul_4  Total_Surgeries  Seoul_Accidents  Seoul_Deaths  \
# count  144.000000  144.000000       144.000000       144.000000    144.000000
# mean     0.441628    0.093264         0.390818         0.553553      0.485764
# std      0.305593    0.276129         0.181320         0.195599      0.202964
# min      0.000000    0.000000         0.000000         0.000000      0.000000
# 25%      0.151381    0.000300         0.262281         0.462645      0.350000
# 50%      0.414196    0.000603         0.370552         0.573791      0.475000
# 75%      0.664690    0.001003         0.505527         0.678659      0.625000
# max      1.000000    1.000000         1.000000         1.000000      1.000000
#
#        ...   Seoul_Gas  Seoul_Temp    Seoul_O3   Seoul_SO3   Seoul_NO2  \
# count  ...  144.000000  144.000000  144.000000  144.000000  144.000000
# mean   ...    0.309253    0.557793    0.388185    0.329604    0.483796
# std    ...    0.294597    0.285951    0.259847    0.192283    0.212419
# min    ...    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    ...    0.046324    0.295139    0.147059    0.166667    0.300000
# 50%    ...    0.208260    0.591667    0.367647    0.333333    0.566667
# 75%    ...    0.582352    0.822222    0.588235    0.500000    0.624074
# max    ...    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          Seoul_CO  Gyeonggi_PM10  Seoul Total Precipitation (mm)  \
# count  144.000000     144.000000                      144.000000
# mean     0.265432       0.445879                        0.098576
# std      0.257265       0.224355                        0.144238
# min      0.000000       0.000000                        0.000000
# 25%      0.000000       0.246094                        0.022834
# 50%      0.200000       0.460938                        0.049381
# 75%      0.400000       0.609375                        0.110433
# max      1.000000       1.000000                        1.000000
#
#        Seoul Mean Wind Speed (m/s)  Seoul Mean Rel. Humid. (%)
# count                   144.000000                  144.000000
# mean                      0.489418                    0.456790
# std                       0.204561                    0.225232
# min                       0.000000                    0.000000
# 25%                       0.333333                    0.305556
# 50%                       0.476190                    0.416667
# 75%                       0.619048                    0.583333
# max                       1.000000                    1.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# ### Define features and target
# Note: We drop 'Year' and 'Month', as they act more as indices than modeling features.

# %%
target = norm_df['Total Sales']
features = norm_df.drop(columns=['Year', 'Month', 'Total Sales'])

# %% [markdown]
# ### Split into training and test data
# To properly train and test our model, we'll split the data into train and test sets, with a 70/30 ratio of training to test data. To do this, we use TrainTestSplit.

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %% [markdown]
# ### First try with Random Forest Regressor

# %%
# initialize regressor
forest = RandomForestRegressor(random_state=42)
forest = forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)

# %% [markdown]
# To benchmark our results, we'll again view the mean squared error (MSE) and root mean squared error (RMSE) of each model. This can be done using scikit-learn's mean_squared_error.

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = mse**.5
print('MSE (Untuned, All Feature Random Forest): ', mse)
print('RMSE (Untuned, All Feature Random Forest): ', rmse)
# Out:
# MSE (Untuned, All Feature Random Forest):  8.992758209904957e-05
# RMSE (Untuned, All Feature Random Forest):  0.009483015453907558

# %% [markdown]
# We can see here that the MSE is already in the scale of __1e-5__! This shows strong predictive strength with our many features. However, they are not necessarily all beneficial to the model. Let's see how we can narrow things down by _removing features and tuning_.

# %% [markdown]
# ### 1. Check correlation plot for extreme features
# Our intial error is very low. There is potential for a not-entirely-independent feature in the data, causing this very accurate data. If this exists, it is interesting to know what causes this interaction, and if there is any conclusion to reach. Also, it may be more meaningful to remove this feature (due to the non-independent nature of the data).

# %%
sns.set(rc={'figure.figsize':(30,24)})
sns.heatmap(norm_df.drop(columns=['Year','Month']).corr(), annot=True);

# %% [markdown]
# ### 2. Closer look at highly correlated features

# %% [markdown]
# It's a little hard to see, but there are actually some interesting feature correlations here! Especially between Seoul infectious disease category 2 and International passenger flight when compared to total sales. Let's take a closer look:

# %%
sns.set(rc={'figure.figsize':(8,6)})
plt.title('Comparing highly correlated values')
sns.heatmap(norm_df.iloc[:,[2,4,11]].corr(), annot=True);

# %% [markdown]
# ### Interesting takeaway
# We can see here that there is a strong relationship between these features. The features, again, are total pharmaceutical sales, Seoul infectious disease category 2 (vaccine preventable viral disease like measles and polio), and total international flight passengers. The connection is not innately obvious, so it is interesting to observe this highly correlated behavior in the features!

# %% [markdown]
# ## Feature Elimination
# Now that we've seen how the model performs with all features and have documented some interesting connections found in the data, let's see how we can improve it by potentially removing some less relevant features.
#
# This will be done in similar fashion to the recursive modeling in the Gas Generation modeling notebook: by using RFECV.

# %% [markdown]
# ### Import additional dependencies

# %%
from sklearn.feature_selection import RFECV
from sklearn.pipeline import Pipeline
from numpy import mean
from numpy import std

# %% [markdown]
# ### Initialize feature eliminator and pipeline

# %%
# create pipeline
rfe = RFECV(estimator=RandomForestRegressor())
model = RandomForestRegressor()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, features, target, scoring='neg_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
# report performance
print('MSE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MSE: -0.000 (0.000)

# %% [markdown]
# The error from this feature elimination is too low to report already! Let's see what features were chosen.

# %% [markdown]
# ### Fit to features and target and show results

# %%
rfe.fit(features, target)
# Out:
# RFECV(estimator=RandomForestRegressor())

# %%
for i in range(features.shape[1]):
 print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 2.000
# Column: 1, Selected True, Rank: 1.000
# Column: 2, Selected False, Rank: 6.000
# Column: 3, Selected False, Rank: 7.000
# Column: 4, Selected False, Rank: 18.000
# Column: 5, Selected False, Rank: 28.000
# Column: 6, Selected False, Rank: 16.000
# Column: 7, Selected False, Rank: 19.000
# Column: 8, Selected False, Rank: 3.000
# Column: 9, Selected False, Rank: 15.000
# Column: 10, Selected False, Rank: 22.000
# Column: 11, Selected False, Rank: 11.000
# Column: 12, Selected False, Rank: 8.000
# Column: 13, Selected False, Rank: 14.000
# Column: 14, Selected False, Rank: 12.000
# Column: 15, Selected False, Rank: 9.000
# Column: 16, Selected False, Rank: 4.000
# Column: 17, Selected False, Rank: 5.000
# Column: 18, Selected False, Rank: 17.000
# Column: 19, Selected False, Rank: 21.000
# Column: 20, Selected False, Rank: 13.000
# Column: 21, Selected False, Rank: 27.000
# Column: 22, Selected False, Rank: 23.000
# Column: 23, Selected False, Rank: 29.000
# Column: 24, Selected False, Rank: 26.000
# Column: 25, Selected False, Rank: 10.000
# Column: 26, Selected False, Rank: 20.000
# Column: 27, Selected False, Rank: 24.000
# Column: 28, Selected False, Rank: 25.000

# %% [markdown]
# Converting this back to our feature names:

# %%
features.columns[1]
# Out:
# 'Seoul_2'

# %% [markdown]
# ## First elimination result:
# According to the recursive feature elimination, the model would work best by only using the data from Seoul infectious disease category 2! This is a bit expected from the high correlation, but perhaps doesn't make for a good model.
#
# __It seems that 'Seoul_2' is too closely related to Total Sales__.
#
# Thus, it will make for a more compelling model to remove Seoul_2 from the features. However, it is still interesting to see the potential performance of performing a regression with only Seoul_2 as a single feature. Let's quickly see how it does:

# %% [markdown]
# ### Using only Seoul_2 as a feature
# A quick aside from the main problem, let's see how the model performs with just the recommended single feature selected.

# %%
# re-split and define the test and training data (features should be changed to only use Seoul_2 data)
X_train, X_test, y_train, y_test = train_test_split(features.Seoul_2, target, test_size=0.3, random_state=42)

# %%
# initialize regressor
forest = RandomForestRegressor(random_state=42)
forest = forest.fit(X_train.array.reshape(-1, 1), y_train)
y_pred = forest.predict(X_test.array.reshape(-1, 1))

# %%
# calculate and present the error
mse = mean_squared_error(y_test, y_pred)
rmse = mse**.5
print('MSE (Seoul_2 Random Forest): ', mse)
print('RMSE (Seoul_2 Random Forest): ', rmse)
# Out:
# MSE (Seoul_2 Random Forest):  5.823805244407725e-07
# RMSE (Seoul_2 Random Forest):  0.0007631386010684905

# %% [markdown]
# ### Results from quick aside and small takeaway:
# The error is quite small, with MSE in the range of 1e-7. This just shows how strongly dependent the data of Seoul_2 and Total Sales was!
#
# As mentioned before, it is really interesting that these have a connection. However, Seoul_2 is a category of disease that is curable through vaccines. As a result, it is highly likely that __more cases of category 2 type diseases would result in more pharmaceutical drug sales!__

# %% [markdown]
# ## Feature Elimination: Seoul_2 removed
# We will then repeat the previous steps, but with Seoul_2 removed from the feature set and see how everything performs.
#
# First, a plain Random Forest Regressor without Seoul_2:

# %% [markdown]
# ### Redefine features and training sets

# %%
features = features.drop(columns='Seoul_2')

# %%
# re-split and define the test and training data (features should be changed remove Seoul_2 data)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %% [markdown]
# ### Test with basic random forest

# %%
# initialize regressor
forest = RandomForestRegressor(random_state=42)
forest = forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)

# %%
# calculate and present the error
mse = mean_squared_error(y_test, y_pred)
rmse = mse**.5
print('MSE (Seoul_2 Removed Random Forest): ', mse)
print('RMSE (Seoul_2 Removed Random Forest): ', rmse)
# Out:
# MSE (Seoul_2 Removed Random Forest):  0.00044073870603484315
# RMSE (Seoul_2 Removed Random Forest):  0.020993777793309215

# %% [markdown]
# We can see here that the error is significantly larger without the effects of using Seoul_2 to predict. However, it is still relatively low.

# %% [markdown]
# ## Recursive Feature Elimination 2

# %%
# create pipeline
rfe = RFECV(estimator=RandomForestRegressor())
model = RandomForestRegressor()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=17)
n_scores = cross_val_score(pipeline, features, target, scoring='neg_mean_squared_error', cv=cv, n_jobs=-1, error_score='raise')

# %%
# report performance
print('MSE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
# Out:
# MSE: -0.001 (0.002)

# %% [markdown]
# The error is a bit larger this time, as expected.

# %%
rfe.fit(features, target)
# Out:
# RFECV(estimator=RandomForestRegressor())

# %%
selected = []
for i in range(features.shape[1]):
    if rfe.support_[i]:
        selected.append(i)
    print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected True, Rank: 1.000
# Column: 1, Selected True, Rank: 1.000
# Column: 2, Selected True, Rank: 1.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected False, Rank: 8.000
# Column: 5, Selected False, Rank: 9.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected True, Rank: 1.000
# Column: 8, Selected False, Rank: 6.000
# Column: 9, Selected True, Rank: 1.000
# Column: 10, Selected False, Rank: 3.000
# Column: 11, Selected True, Rank: 1.000
# Column: 12, Selected True, Rank: 1.000
# Column: 13, Selected True, Rank: 1.000
# Column: 14, Selected True, Rank: 1.000
# Column: 15, Selected True, Rank: 1.000
# Column: 16, Selected True, Rank: 1.000
# Column: 17, Selected True, Rank: 1.000
# Column: 18, Selected True, Rank: 1.000
# Column: 19, Selected True, Rank: 1.000
# Column: 20, Selected False, Rank: 5.000
# Column: 21, Selected True, Rank: 1.000
# Column: 22, Selected False, Rank: 2.000
# Column: 23, Selected False, Rank: 7.000
# Column: 24, Selected True, Rank: 1.000
# Column: 25, Selected True, Rank: 1.000
# Column: 26, Selected False, Rank: 4.000
# Column: 27, Selected True, Rank: 1.000

# %% [markdown]
# There are more selected features this time! Let's present it in a more easily understandable way.

# %%
print('Selected features: ', *features.iloc[:,selected].columns, sep='\n')
# Out:
# Selected features:
# Seoul_1
# Seoul_3
# Seoul_4
# Total_Surgeries
# Seoul_Injured
# International flight (passenger)
# Total_Buildings
# Other_Material_Buildings
# Industrial_Use_Buildings
# Edu_Social_Use_Buildings
# Other_Use_Buildings
# Total_Fires
# Seoul_Fires
# Seoul_Elec
# Seoul_Gas
# Seoul_Temp
# Seoul_SO3
# Gyeonggi_PM10
# Seoul Total Precipitation (mm)
# Seoul Mean Rel. Humid. (%)

# %%
print(len(selected))
# Out:
# 20

# %% [markdown]
# ## Second Elimination Result:
# Without the overpowering effect of Seoul_2, we have quite a few other features that are deemed fit to use for modeling.
#
# In this case, 20 out of the 29 total features were selected to be useful for modeling. Let's see how the result will look when using these features.
#
# NOTE: I also tried using a few different random_states for train_test_split and for repeatedKFold. This actually caused quite a lot of variation in both error reporting and feature selection. Perhaps the target or features need to be further inspected, as this is not typical behavior for a well-trained model.

# %% [markdown]
# ///Old result...?///
#
# The 7 features are listed above, and include infectious disease data (category 1, 3, 4), total international flights, constructed buildings made of other materials (materials that didn't fit into a category), and fires across Korea and in Seoul specifically.

# %% [markdown]
# ### Drop features
# Remove features as decided by recursive feature elimination.

# %%
features = features.iloc[:, selected]
features
# Out:
#       Seoul_1   Seoul_3   Seoul_4  Total_Surgeries  Seoul_Injured  \
# 0    0.001255  0.369730  0.000000         0.509563       0.187292
# 1    0.001255  0.369730  0.000000         0.176812       0.230482
# 2    0.001255  0.369730  0.000000         0.283121       0.526578
# 3    0.001255  0.369730  0.000000         0.174357       0.657807
# 4    0.001255  0.369730  0.000000         0.153741       0.849252
# ..        ...       ...       ...              ...            ...
# 139  1.000000  0.855567  0.000747         0.461032       0.580150
# 140  1.000000  0.855567  0.000747         0.421975       0.490864
# 141  1.000000  0.855567  0.000747         0.595267       0.699751
# 142  1.000000  0.855567  0.000747         0.589796       0.649917
# 143  1.000000  0.855567  0.000747         0.723425       0.471761
#
#      International flight (passenger)  Total_Buildings  \
# 0                            0.165475         0.299520
# 1                            0.127132         0.156452
# 2                            0.094791         0.603650
# 3                            0.085625         0.776561
# 4                            0.111076         0.747679
# ..                                ...              ...
# 139                          1.000000         0.522574
# 140                          0.765591         0.493052
# 141                          0.861722         0.731092
# 142                          0.793796         0.637016
# 143                          0.905355         0.464938
#
#      Other_Material_Buildings  Industrial_Use_Buildings  \
# 0                    0.136674                  0.716969
# 1                    0.136674                  0.401554
# 2                    0.189066                  0.944301
# 3                    0.141230                  1.000000
# 4                    0.093394                  0.959197
# ..                        ...                       ...
# 139                  0.608200                  0.226684
# 140                  0.678815                  0.191710
# 141                  1.000000                  0.379534
# 142                  0.731207                  0.351684
# 143                  0.911162                  0.145078
#
#      Edu_Social_Use_Buildings  Other_Use_Buildings  Total_Fires  Seoul_Fires  \
# 0                    0.534456             0.187883          1.0     1.000000
# 1                    0.189893             0.097201          1.0     1.000000
# 2                    0.468606             0.321127          1.0     1.000000
# 3                    0.635528             0.400690          1.0     1.000000
# 4                    0.768760             0.365798          1.0     1.000000
# ..                        ...                  ...          ...          ...
# 139                  0.145482             0.750000          0.0     0.397163
# 140                  0.321593             0.758819          0.0     0.397163
# 141                  0.341501             1.000000          0.0     0.397163
# 142                  0.376723             0.886503          0.0     0.397163
# 143                  0.271057             0.710123          0.0     0.397163
#
#      Seoul_Elec  Seoul_Gas  Seoul_Temp  Seoul_SO3  Gyeonggi_PM10  \
# 0      0.037823   0.864606    0.152778   0.777778       0.588542
# 1      0.052013   0.845177    0.166667   0.592593       0.711806
# 2      0.014207   0.596491    0.402778   0.333333       0.715278
# 3      0.060069   0.324808    0.591667   0.259259       0.593750
# 4      0.077424   0.133759    0.691667   0.351852       0.748264
# ..          ...        ...         ...        ...            ...
# 139    0.028324   0.023998    0.955556   0.166667       0.078125
# 140    0.015798   0.017972    0.827778   0.000000       0.031250
# 141    0.009375   0.055440    0.655556   0.000000       0.203125
# 142    0.013203   0.283919    0.411111   0.166667       0.359375
# 143    0.014882   0.567942    0.238889   0.166667       0.359375
#
#      Seoul Total Precipitation (mm)  Seoul Mean Rel. Humid. (%)
# 0                          0.015650                    0.194444
# 1                          0.013263                    0.083333
# 2                          0.047657                    0.361111
# 3                          0.034041                    0.194444
# 4                          0.086384                    0.416667
# ..                              ...                         ...
# 139                        0.168435                    0.722222
# 140                        0.123607                    0.611111
# 141                        0.049072                    0.527778
# 142                        0.069673                    0.361111
# 143                        0.019982                    0.416667
#
# [144 rows x 20 columns]

# %%
# re-split and define the test and training data (drop additional features)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %% [markdown]
# ### Evaluate resulting model

# %%
# initialize regressor
forest = RandomForestRegressor(random_state=42)
forest = forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)

# %%
# calculate and present the error
mse = mean_squared_error(y_test, y_pred)
rmse = mse**.5
print('MSE (Second Elimination Random Forest): ', mse)
print('RMSE (Second Elimination Random Forest): ', rmse)
# Out:
# MSE (Second Elimination Random Forest):  0.0003553015011870201
# RMSE (Second Elimination Random Forest):  0.018849442994078633

# %% [markdown]
# The result is slightly better than than previously with all features, reducing from ~0.02 RMSE to ~0.018 RMSE. This error changes with different random_states as well, so it isn't fully dependable as a metric for a good model.

# %% [markdown]
# ## Quick Try with Hyperparameter Tuning
# The data isn't especially stable yet. However, we'll still try to see how hyperparameter tuning effects the result for now.
#
# I will use GridSearch and test parameters to find a good balance for this model.

# %%
# define models and parameters
model = RandomForestRegressor()
grid = {
    'n_estimators': [50, 75, 100, 150, 200, 400],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [8,9,10],
    'random_state': [42]
}

# define evaluation
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=17)

# %%
# define grid search
search = GridSearchCV(model, grid, scoring='neg_mean_squared_error', n_jobs=-1, cv=cv)

# start grid search
result = search.fit(features, target)

# %%
print(result.best_score_)
print(result.best_params_)
# Out:
# -0.0006142407715772446
# {'max_depth': 9, 'max_features': 'sqrt', 'n_estimators': 100, 'random_state': 42}

# %% [markdown]
# ### Selected Parameters:
# The selected parameters are as shown above, with:
# - max_depth: 9
# - max_features: sqrt
# - n_estimators: 100
# - random_state:42

# %% [markdown]
# ### Initialize Random Forest again with new hyperparameters

# %%
# initialize again, with tuned hyperparameters
forest_tuned = RandomForestRegressor(max_depth=9, max_features='sqrt', n_estimators=100, random_state=42)
forest_tuned = forest_tuned.fit(X_train, y_train)
y_pred = forest_tuned.predict(X_test)

# %%
#error
mse = mean_squared_error(y_test, y_pred)
rmse = mse**.5
print('MSE (Tuned, Feature Dropped Random Forest): ', mse)
print('RMSE (Tuned, Feature Dropped Random Forest): ', rmse)
# Out:
# MSE (Tuned, Feature Dropped Random Forest):  0.0015301303565234783
# RMSE (Tuned, Feature Dropped Random Forest):  0.03911688071055102

# %% [markdown]
# In this case, performance is actually worse than before. Interesting to see that despite tuning, the result has not improved! Perhaps this would be different with a different performance metric and different random_state.
#
# The main takeway from this portion of modeling is that the data is not very stable, and overfitting seems to occur often. Let's see how we can fix this problem.
